# %%
a = int(input())
b = int(input())
c = int(input())
d = int(input())

if a == 0 and b == 0 and (c == 0 or d == 0):
    print("INF")
elif (a == b and c == d) or (a == 0 and b == 0 and c != 0 and d != 0):
    print("NO")
else:
    print(-b / a)
# Out:
# 2.0

# %%
s = input()

print(s[2])
print(s[-2])
print(s[:5])
print(s[:-2])
print(s[::2])
print(s[1::2])
print(s[::-1])
print(s[::-2])
print(len(s))
# Out:
# l
# l
# Hello
# Hel
# Hlo
# el
# olleH
# olH
# 5

# %%
a = float(input())
b = float(input())
c = float(input())
d = b ** 2 - 4 * a * c
if d < 0:
    pass
elif d == 0:    print(int(-b / (2 * a)))
else:
    d = The real coefficients 
a
a, 
b
b, 
c
c are given, and 
a
≠
0
a

=0. Solve the quadratic equation 
a
x
2
+
b
x
+
c
=
0
ax 
2
 +bx+c=0 and derive all its roots.

Input format
Three real numbers.

Output format
If the equation has two roots then output two roots in ascending order;

if one root then output one number;

if there are no roots then do not output anything.
    res_1 = (-b + d) / (2 * a)
    res_2 = (-b - d) / (2 * a)
    if (res_1 == int(res_1)) and (res_2 == int(res_2)):
        print(int(min(res_1, res_2)), int(max(res_1, res_2)))
    else:
        print("{:.6f} {:.6f}".format(min(res_1, res_2), max(res_1, res_2)))
# Out:
# 0.423966 7.076034

# %%
a = int(input())
b = int(input())
c = int(input())
d = int(input())
if a == 0 and b == 0:
    if c == 0 and d == 0:
        print("NO")
    elif c == 0 and d != 0:
        print("INF")
    else:
        print("INF")
elif a == 0 and b != 0:
    print("NO")
else:
    if (-b) % a != 0:
        print("NO")
    else:
        x = (-b) // a
        if c * x + d == 0:
            print("NO")
        else:
            print(x)
# Out:
# 2

# %%
a = float(input())
b = float(input())
c = float(input())
d = b ** 2 - 4 * a * c

if d < 0:
    pass
elif d == 0:
    root = -b / (2 * a)
    if abs(root - round(root)) < 1e-10:
        print(int(round(root)))
    else:
        print("{:.6f}".format(root))
else:
    d = d ** 0.5
    res_1 = (-b + d) / (2 * a)
    res_2 = (-b - d) / (2 * a)
    r1, r2 = min(res_1, res_2), max(res_1, res_2)
    if abs(r1 - round(r1)) < 1e-10 and abs(r2 - round(r2)) < 1e-10:
        print(int(round(r1)), int(round(r2)))
    else:
        print("{:.6f} {:.6f}".format(r1, r2))
# Out:
# -1
